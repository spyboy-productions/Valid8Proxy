# %% [markdown]
# # Valid8Proxy - Tool designed for fetching, validating, and storing working proxies.
#
# **Install and use Valid8Proxy right here in Colab or Jupyter.**

# %%
# 📦 Clone the repo and install dependencies
# !git clone https://github.com/spyboy-productions/Valid8Proxy.git
# %cd Valid8Proxy
# !pip3 install -r requirements.txt

# %%
# 📘 Show command help
# !python3 Valid8Proxy.py --h

# %% [markdown]
# ## ✅ Example Usage

# %%
# 🔍 Test on https://apple.com
# !python3 Valid8Proxy.py --type https --count 3 --test-url https://apple.com
